# %%
import os

DB_CONFIG = {
    "host": "localhost",
    "port": 5432,
    "user": "postgres",
    "password": "admin",
    "database": "nspcc_dwh"
}

DATA_DIR = os.path.abspath(os.path.join(os.getcwd(), '..', 'data'))  # Adjust path if needed
SCHEMA = "nspcc"

# %%
# load.py

import json

import os
import json
import time
import psycopg2
# from config.db_config import DB_CONFIG

def load_json_files():
    all_data = []
    conn = psycopg2.connect(**DB_CONFIG)
    cursor = conn.cursor()

    for file in os.listdir(DATA_DIR):
        if not file.endswith(".json"):
            continue

        file_path = os.path.join(DATA_DIR, file)
        print(f"Processing file: {file_path}")
        start_time = time.time()
        record_count = 0
        status = 'completed'
        error_message = None

        try:
            with open(file_path, 'r') as f:
                data = json.load(f)
                all_data.extend(data)
                record_count = len(data)
        except Exception as e:
            status = 'failed'
            error_message = str(e)
            print(f"❌ JSON decode error in file: {file} -> {e}")

        processing_time = int(time.time() - start_time)

        # Insert into processed_file_log
        cursor.execute(f"""
            INSERT INTO nspcc.file_error_logging (file_name, record_count, processing_time_seconds, status, error_message)
            VALUES (%s, %s, %s, %s, %s)
        """, (file, record_count, processing_time, status, error_message))

    conn.commit()
    cursor.close()
    conn.close()
    return all_data

# %%
# transform.py

from datetime import datetime

def flatten_data(raw_data):
    fact_rows, dim_customers, dim_regions, dim_payments = [], [], [], []

    for entry in raw_data:
        # print(entry)
        cust_id = entry.get("customer_id")
        profile = entry.get("customer_profile", {})
        region = profile.get("region", "Unknown")

        dim_customers.append({
            "customer_id": cust_id,
            "email": entry.get("email"),
            "shirt_size": profile.get("shirt_size"),
            "donates_to_charity": profile.get("donates_to_charity"),
            "bikes_to_work": profile.get("bikes_to_work")
        })
        is_london = "london" in region.strip().lower()

        dim_regions.append({
            "region": region,
            "is_london": is_london
        })

        donations = entry.get("donations") or []
        for d in donations:
            payment_date = d.get("payment_date")
            dim_payments.append({"payment_method": d.get("payment_method")})

            fact_rows.append({
                "payment_id": d.get("payment_id"),
                "customer_id": cust_id,
                "amount": d.get("amount"),
                "status": d.get("status"),
                "payment_method": d.get("payment_method"),
                "payment_date": payment_date,
                "region": region
            })

    return fact_rows, dim_customers, dim_payments, dim_regions

# %%
#load.py

import psycopg2
from datetime import datetime

# SCD2 Type Handling for Dimension tables
def insert_scd2(cursor, table, keys, record):
    schema_table = f"{SCHEMA}.{table}"
    cursor.execute(f"SELECT 1 FROM {schema_table} WHERE {' AND '.join([f'{k}=%s' for k in keys])} AND is_active='Y'",
        [record[k] for k in keys]
    )
    print(
    f"SELECT 1 FROM {schema_table} WHERE {' AND '.join([f'{k}=%s' for k in keys])} AND is_active='Y'",
    [record[k] for k in keys]
    )
    if cursor.fetchone():
        schema_table = f"{SCHEMA}.{table}"
        cursor.execute(f"""
            UPDATE {schema_table} SET effective_end_date=%s, is_active='N'
            WHERE {' AND '.join([f'{k}=%s' for k in keys])} AND is_active='Y'
        """, [datetime.today()] + [record[k] for k in keys])

    columns = ', '.join(record.keys())
    values = ', '.join(['%s'] * len(record))
    schema_table = f"{SCHEMA}.{table}"
    cursor.execute(f"""
        INSERT INTO {schema_table} ({columns}, effective_start_date, effective_end_date, is_active)
        VALUES ({values}, %s, NULL, 'Y')
    """, list(record.values()) + [datetime.today()])

def load_to_db(fact_rows, dim_customers, dim_payments, dim_regions):
    conn = psycopg2.connect(**DB_CONFIG)
    cursor = conn.cursor()

    unique_regions = {}
    for rec in dim_regions:
        unique_regions[rec['region']] = rec
    
    
    unique_payments = {}
    for rec in dim_payments:
        unique_payments[rec['payment_method']] = rec
    
    # Load dimension tables with unique records
    for rec in unique_regions.values():
        insert_scd2(cursor, "dim_region", ["region"], rec)
        
    for rec in dim_customers:
        insert_scd2(cursor, "dim_customer", ["customer_id"], rec)
        
    for rec in unique_payments.values():
        insert_scd2(cursor, "dim_payment_method", ["payment_method"], rec)


    for row in fact_rows:
        # 1. Get surrogate keys from dimension tables
        cursor.execute(f"SELECT customer_key FROM {SCHEMA}.dim_customer WHERE customer_id = %s AND is_active = TRUE", (row["customer_id"],))
        customer_key = cursor.fetchone()
        
        cursor.execute(f"SELECT region_key FROM {SCHEMA}.dim_region WHERE region = %s AND is_active = TRUE", (row["region"],))
        region_key = cursor.fetchone()
    
        cursor.execute(f"SELECT payment_method_key FROM {SCHEMA}.dim_payment_method WHERE payment_method = %s AND is_active = TRUE", (row["payment_method"],))
        payment_method_key = cursor.fetchone()
    
        cursor.execute(f"SELECT date_id FROM {SCHEMA}.dim_date WHERE full_date = %s", (row["payment_date"],))
        date_key = cursor.fetchone()
    
        if not (customer_key and region_key and payment_method_key and date_key):
            print(f"Skipping row {row['payment_id']} due to missing dimension keys.")
            continue
    
        # 2. Insert into fact_donations
        cursor.execute(f"""
            INSERT INTO {SCHEMA}.fact_donations (
                payment_id, customer_key, date_key, payment_method_key, region_key,
                amount, status
            )
            VALUES (%s, %s, %s, %s, %s, %s, %s)
            ON CONFLICT (payment_id) DO NOTHING
        """, (
            row["payment_id"],
            customer_key[0],
            date_key[0],
            payment_method_key[0],
            region_key[0],
            row["amount"],
            row["status"]
        ))

    conn.commit()
    cursor.close()
    conn.close()

# %%
# main.py

import logging

logging.basicConfig(filename='etl.log', level=logging.INFO)

def main():
    logging.info("Starting ETL job")
    raw_data = load_json_files()
    logging.info(f"Loaded {len(raw_data)} customer records")
    fact_rows, dim_customers, dim_payments, dim_regions = flatten_data(raw_data)
    load_to_db(fact_rows, dim_customers, dim_payments, dim_regions)
    logging.info("ETL job complete")

main()
# Out:
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_0.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_1.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_10.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_11.json
# ❌ JSON decode error in file: api_response_11.json -> Extra data: line 1 column 5 (char 4)
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_12.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_13.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_14.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_15.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_16.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_17.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_18.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_19.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_2.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_20.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_21.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_22.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_23.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_24.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_25.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_26.json
# ❌ JSON decode error in file: api_response_26.json -> Extra data: line 1 column 5 (char 4)
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_27.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_28.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_29.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_3.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_30.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_31.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_32.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_33.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_34.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_35.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_36.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_37.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_38.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_39.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_4.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_40.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_41.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_42.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_43.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_44.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_45.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_46.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_47.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_48.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_49.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_5.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_6.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_7.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_8.json
# Processing file: C:\Sobz\Learning\Workshops\Interview_Tasks\Solutions\nspcc_etl\data\api_response_9.json
# SELECT 1 FROM nspcc.dim_region WHERE region=%s AND is_active='Y' ['South West']
# SELECT 1 FROM nspcc.dim_region WHERE region=%s AND is_active='Y' ['East of England']
# SELECT 1 FROM nspcc.dim_region WHERE region=%s AND is_active='Y' ['North West']
# SELECT 1 FROM nspcc.dim_region WHERE region=%s AND is_active='Y' ['Midlands']
# SELECT 1 FROM nspcc.dim_region WHERE region=%s AND is_active='Y' ['Yorkshire and the Humber']
# SELECT 1 FROM nspcc.dim_region WHERE region=%s AND is_active='Y' ['London and South East']
# SELECT 1 FROM nspcc.dim_region WHERE region=%s AND is_active='Y' ['North East']
# SELECT 1 FROM nspcc.dim_region WHERE region=%s AND is_active='Y' ['Scotland']
# SELECT 1 FROM nspcc.dim_region WHERE region=%s AND is_active='Y' ['Wales']
# SELECT 1 FROM nspcc.dim_region WHERE region=%s AND is_active='Y' ['Northern Ireland']
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [1]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [2]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [3]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [4]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [5]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [6]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [7]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [8]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [9]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [10]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [51]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [52]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [53]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [54]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [55]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [61]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [62]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [63]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [64]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [65]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [66]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [67]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [68]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [69]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [70]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [71]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [72]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [73]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [74]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [75]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [76]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [77]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [78]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [79]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [80]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [81]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [82]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [83]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [84]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [85]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [86]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [87]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [88]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [89]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [90]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [91]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [92]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [93]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [94]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [95]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [96]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [97]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [98]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [99]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [100]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [11]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [12]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [13]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [14]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [15]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [101]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [102]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [103]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [104]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [105]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [106]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [107]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [108]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [109]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [110]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [111]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [112]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [113]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [114]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [115]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [116]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [117]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [118]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [119]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [120]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [121]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [122]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [123]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [124]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [125]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [126]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [127]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [128]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [129]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [130]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [136]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [137]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [138]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [139]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [140]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [141]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [142]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [143]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [144]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [145]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [146]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [147]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [148]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [149]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [150]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [16]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [17]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [18]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [19]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [20]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [151]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [152]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [153]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [154]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [155]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [156]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [157]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [158]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [159]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [160]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [161]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [162]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [163]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [164]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [165]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [166]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [167]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [168]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [169]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [170]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [171]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [172]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [173]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [174]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [175]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [176]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [177]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [178]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [179]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [180]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [181]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [182]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [183]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [184]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [185]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [186]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [187]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [188]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [189]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [190]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [191]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [192]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [193]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [194]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [195]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [196]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [197]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [198]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [199]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [200]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [21]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [22]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [23]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [24]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [25]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [201]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [202]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [203]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [204]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [205]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [206]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [207]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [208]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [209]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [210]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [211]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [212]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [213]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [214]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [215]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [216]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [217]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [218]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [219]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [220]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [221]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [222]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [223]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [224]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [225]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [226]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [227]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [228]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [229]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [230]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [231]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [232]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [233]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [234]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [235]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [236]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [237]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [238]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [239]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [240]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [241]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [242]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [243]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [244]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [245]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [246]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [247]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [248]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [249]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [250]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [26]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [27]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [28]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [29]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [30]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [31]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [32]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [33]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [34]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [35]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [36]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [37]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [38]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [39]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [40]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [41]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [42]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [43]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [44]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [45]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [46]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [47]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [48]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [49]
# SELECT 1 FROM nspcc.dim_customer WHERE customer_id=%s AND is_active='Y' [50]
# SELECT 1 FROM nspcc.dim_payment_method WHERE payment_method=%s AND is_active='Y' ['debit card']
# SELECT 1 FROM nspcc.dim_payment_method WHERE payment_method=%s AND is_active='Y' ['credit card']
# SELECT 1 FROM nspcc.dim_payment_method WHERE payment_method=%s AND is_active='Y' ['PayPal']
